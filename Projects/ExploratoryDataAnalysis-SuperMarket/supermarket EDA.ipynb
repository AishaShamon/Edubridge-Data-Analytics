# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Reading the data

# %%
d=pd.read_excel('Supermarket.xlsx')

# %%
d
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## To check how many rows and columns

# %%
d.shape
# Out:
# (1000, 17)

# %% [markdown]
# .Dataset comprises 1000 observations(rows) and 17 features(columns).

# %% [markdown]
# ## To print fields name

# %%
d.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# ## To check the data type of attributes

# %%
d.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %% [markdown]
# Dataset has 7 Float columns, 1 datetime column,1 integer column and 8 object (string) Columns

# %% [markdown]
# ## print information of a dataset

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):

# %% [markdown]
# ## To check is there any missing value

# %%
d.isnull()
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0         False     False   False  False  False  False    False  False
# ...

# %% [markdown]
# ## number of null values in a dataset

# %%
d.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# This confirms that data has no null values

# %% [markdown]
# ## To show unique values

# %%
d.nunique()
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %% [markdown]
# ## To print top 10 records

# %%
d.head(10)
# Out:
#   Branch       City  Gender            Product line  price  Quantity   Tax 5%  \
# 0      A     Yangon  Female       Health and beauty  74.69         7  26.1415
# 1      C  Naypyitaw  Female  Electronic accessories  15.28         5   3.8200
# 2      A     Yangon    Male      Home and lifestyle  46.33         7  16.2155
# 3      A     Yangon    Male       Health and beauty  58.22         8  23.2880
# 4      A     Yangon    Male       Sports and travel  86.31         7  30.2085
# 5      C  Naypyitaw    Male  Electronic accessories  85.39         7  29.8865
# 6      A     Yangon  Female  Electronic accessories  68.84         6  20.6520
# 7      C  Naypyitaw  Female      Home and lifestyle  73.56        10  36.7800
# 8      A     Yangon  Female       Health and beauty  36.26         2   3.6260
# 9      B   Mandalay  Female      Food and beverages  54.84         3   8.2260
#
#       Total      Payment    cogs  percentage   income  Rating
# ...

# %% [markdown]
# ## To print bottom 10 records

# %%
d.tail(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 990  886-18-2897      A     Yangon        Normal  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 992  745-74-0715      A     Yangon        Normal    Male
# 993  690-01-6631      B   Mandalay        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 990      Food and beverages       56.56         5  14.1400   296.9400
# 991       Sports and travel       76.60        10  38.3000   804.3000
# 992  Electronic accessories       58.03         2   5.8030   121.8630
# ...

# %% [markdown]
# ## Drop the columns which not required

# %%
d.drop(['Invoice ID','Date','Time'],axis=1,inplace=True)

# %%
d
# Out:
#     Branch       City  Gender            Product line  Unit price  Quantity  \
# 0        A     Yangon  Female       Health and beauty       74.69         7
# 1        C  Naypyitaw  Female  Electronic accessories       15.28         5
# 2        A     Yangon    Male      Home and lifestyle       46.33         7
# 3        A     Yangon    Male       Health and beauty       58.22         8
# 4        A     Yangon    Male       Sports and travel       86.31         7
# ..     ...        ...     ...                     ...         ...       ...
# 995      C  Naypyitaw    Male       Health and beauty       40.35         1
# 996      B   Mandalay  Female      Home and lifestyle       97.38        10
# 997      A     Yangon    Male      Food and beverages       31.84         1
# 998      A     Yangon    Male      Home and lifestyle       65.82         1
# 999      A     Yangon  Female     Fashion accessories       88.34         7
#
# ...

# %% [markdown]
# ## Rename columns

# %%
d.rename(columns={'gross margin percentage':'percentage','gross income':'income','Unit price':'price'},inplace=True)

# %%
d
# Out:
#     Branch       City  Gender            Product line  price  Quantity  \
# 0        A     Yangon  Female       Health and beauty  74.69         7
# 1        C  Naypyitaw  Female  Electronic accessories  15.28         5
# 2        A     Yangon    Male      Home and lifestyle  46.33         7
# 3        A     Yangon    Male       Health and beauty  58.22         8
# 4        A     Yangon    Male       Sports and travel  86.31         7
# ..     ...        ...     ...                     ...    ...       ...
# 995      C  Naypyitaw    Male       Health and beauty  40.35         1
# 996      B   Mandalay  Female      Home and lifestyle  97.38        10
# 997      A     Yangon    Male      Food and beverages  31.84         1
# 998      A     Yangon    Male      Home and lifestyle  65.82         1
# 999      A     Yangon  Female     Fashion accessories  88.34         7
#
#       Tax 5%      Total      Payment    cogs  percentage   income  Rating
# ...

# %% [markdown]
# ## To check is there any duplicated value

# %%
d.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## To print statistical information

# %%
d.describe()
# Out:
#              price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#          percentage       income      Rating
# count  1.000000e+03  1000.000000  1000.00000
# mean   4.761905e+00    15.379369     6.97270
# std    6.131498e-14    11.708825     1.71858
# min    4.761905e+00     0.508500     4.00000
# 25%    4.761905e+00     5.924875     5.50000
# 50%    4.761905e+00    12.088000     7.00000
# ...

# %% [markdown]
# ## Statistic Figures

# %%
d['Quantity'].count()
# Out:
# 1000

# %%
d['Total'].mean()
# Out:
# 322.96674900000005

# %%
d['Total'].max()
# Out:
# 1042.65

# %%
d['Rating'].max()
# Out:
# 10.0

# %%
d['Rating'].min()
# Out:
# 4.0

# %%
d['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
d['Payment'].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
d['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
d1=d.copy()
d1=d1.pivot_table('price',columns='Product line',aggfunc='sum')
d1
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# price                        9103.77             10173.35             9745.54
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# price                   8337.88             8850.71            9460.88

# %%
d1=d.copy()
d1=d1.pivot_table('price',columns='Product line',aggfunc='mean')
d1
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# price                      53.551588            57.153652           56.008851
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# price                 54.854474           55.316937          56.993253

# %%
d1=d.copy()
d1=d1.pivot_table('income',columns='City',aggfunc='max')
d1
# Out:
# City    Mandalay  Naypyitaw  Yangon
# income     48.69      49.65   49.49

# %% [markdown]
# ## Let's find which branch was most successful in terms of Total (revenue?) and Ratings

# %%
d.groupby('Branch')['Total'].sum().sort_values(ascending=False)
# Out:
# Branch
# C    110568.7065
# A    106200.3705
# B    106197.6720
# Name: Total, dtype: float64

# %%
d.groupby('Branch')['Rating'].mean().sort_values(ascending=False)
# Out:
# Branch
# C    7.072866
# A    7.027059
# B    6.818072
# Name: Rating, dtype: float64

# %% [markdown]
# Branch c has heighest revenue and ratings

# %% [markdown]
# ##  product line that  have heighest price

# %%
n=d.groupby('Product line').price.sum().sort_values(ascending=False)
n
# Out:
# Product line
# Fashion accessories       10173.35
# Food and beverages         9745.54
# Sports and travel          9460.88
# Electronic accessories     9103.77
# Home and lifestyle         8850.71
# Health and beauty          8337.88
# Name: price, dtype: float64

# %% [markdown]
# Fashion accessories have heighest price

# %% [markdown]
# ## City which have heighest revenue

# %%
n=d.groupby('City').Total.max().sort_values(ascending=False)
n
# Out:
# City
# Naypyitaw    1042.65
# Yangon       1039.29
# Mandalay     1022.49
# Name: Total, dtype: float64

# %% [markdown]
# Naypyitaw City  have heighest revenue

# %%
pd.crosstab(d['Payment'],d['City'])
# Out:
# City         Mandalay  Naypyitaw  Yangon
# Payment
# Cash              110        124     110
# Credit card       109         98     104
# Ewallet           113        106     126

# %%
city_Total_d=pd.pivot_table(data=d[['City','Total']],
                            index=['City'],
                            values='Total',
                            aggfunc='sum')
city_Total_d.sort_values(by='Total',ascending=False).head(10)
# Out:
#                  Total
# City
# Naypyitaw  110568.7065
# Yangon     106200.3705
# Mandalay   106197.6720

# %%
product_cogs_d=pd.pivot_table(data=d[['Product line','cogs']],
                            index=['Product line'],
                            values='cogs',
                            aggfunc='max')
product_cogs_d.sort_values(by='cogs',ascending=False).head(10)
# Out:
#                           cogs
# Product line
# Fashion accessories     993.00
# Food and beverages      985.20
# Home and lifestyle      975.00
# Sports and travel       954.40
# Health and beauty       905.00
# Electronic accessories  897.57

# %%
product_cogs_d=pd.pivot_table(data=d[['Product line','cogs']],
                            index=['Product line'],
                            values='cogs',
                            aggfunc='sum')
product_cogs_d.sort_values(by='cogs',ascending=False).head(10)
# Out:
#                             cogs
# Product line
# Food and beverages      53471.28
# Sports and travel       52497.93
# Electronic accessories  51750.03
# Fashion accessories     51719.90
# Home and lifestyle      51297.06
# Health and beauty       46851.18

# %%
city_Tax_d=pd.pivot_table(data=d[['City','Tax 5%']],
                            index=['City'],
                            values='Tax 5%',
                            aggfunc='max')
product_Tax_d.sort_values(by='Tax 5%',ascending=False).head(10)
# Out:
#            Tax 5%
# City
# Naypyitaw   49.65
# Yangon      49.49
# Mandalay    48.69

# %%
product_Total_d=pd.pivot_table(data=d[['Product line','Total']],
                            index=['Product line'],
                            values='Total',
                            aggfunc='sum')
product_Total_d.sort_values(by='Total',ascending=False).head(10)
# Out:
#                              Total
# Product line
# Food and beverages      56144.8440
# Sports and travel       55122.8265
# Electronic accessories  54337.5315
# Fashion accessories     54305.8950
# Home and lifestyle      53861.9130
# Health and beauty       49193.7390

# %%
product_Tax_d=pd.pivot_table(data=d[['Product line','Tax 5%']],
                            index=['Product line'],
                            values='Tax 5%',
                            aggfunc='max')
product_Tax_d.sort_values(by='Tax 5%',ascending=False).head(10)
# Out:
#                          Tax 5%
# Product line
# Fashion accessories     49.6500
# Food and beverages      49.2600
# Home and lifestyle      48.7500
# Sports and travel       47.7200
# Health and beauty       45.2500
# Electronic accessories  44.8785

# %%
product_Total_d=pd.pivot_table(data=d[['Product line','Payment','Total']],
                            index=['Product line','Payment'],
                            values='Total',
                            aggfunc='sum')
product_Total_d.sort_values(by='Total',ascending=False).head(10)
# Out:
#                                          Total
# Product line           Payment
# Home and lifestyle     Ewallet      21289.8420
# Electronic accessories Cash         20729.9820
# Food and beverages     Credit card  20235.1905
# Fashion accessories    Ewallet      19357.0335
# Food and beverages     Cash         19210.8735
# Sports and travel      Cash         18873.8130
# Home and lifestyle     Cash         18589.0005
# Sports and travel      Ewallet      18432.7605
# Electronic accessories Ewallet      18179.5320
# Sports and travel      Credit card  17816.2530

# %%
d
# Out:
#     Branch       City  Gender            Product line  price  Quantity  \
# 0        A     Yangon  Female       Health and beauty  74.69         7
# 1        C  Naypyitaw  Female  Electronic accessories  15.28         5
# 2        A     Yangon    Male      Home and lifestyle  46.33         7
# 3        A     Yangon    Male       Health and beauty  58.22         8
# 4        A     Yangon    Male       Sports and travel  86.31         7
# ..     ...        ...     ...                     ...    ...       ...
# 995      C  Naypyitaw    Male       Health and beauty  40.35         1
# 996      B   Mandalay  Female      Home and lifestyle  97.38        10
# 997      A     Yangon    Male      Food and beverages  31.84         1
# 998      A     Yangon    Male      Home and lifestyle  65.82         1
# 999      A     Yangon  Female     Fashion accessories  88.34         7
#
#       Tax 5%      Total      Payment    cogs  percentage   income  Rating
# ...

# %% [markdown]
# ## average spend on each branch

# %%
plt.bar(d['Branch'],d['Total'])
plt.title('TOTAL',fontsize=15,color='red')
plt.xlabel('City',fontsize=15)
plt.ylabel('Total',fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# A branch has heighest  total.
# B branch has lowest total

# %%
plt.bar(d['City'],d['Total'])
plt.title('TOTAL',fontsize=15,color='red')
plt.xlabel('City',fontsize=15)
plt.ylabel('Total',fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# Yangon city has heighest total .
# Mandalay city has lowest total

# %%
plt.figure(figsize=(13,4))
plt.bar('Product line','income', data=d,color='green')
plt.show()

# %% [markdown]
# Fashion accessories ,home and life style and Food and beverages have high income

# %%
plt.figure(figsize=(18,5))
plt.bar('Product line','Tax 5%', data=d,color='green')
plt.show()

# %%
print(d['Product line'].value_counts())
plt.figure(figsize=(10,6))
sns.countplot(x=d['Product line'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %% [markdown]
# Most of the people attracted towards fashion accesssories and electronic accessories

# %%
sns.countplot(x='Payment',data=d,palette='coolwarm')
plt.show()

# %% [markdown]
# Most of the people use Ewallet paymentmode compared to credit card

# %%
plt.title('Payment',fontsize=20)
d['Payment'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.title('Product line',fontsize=20)
d['Product line'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.title('Gender',fontsize=20)
d['Gender'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# Female shopping slightly heigher than compared to male

# %%
plt.title('City',fontsize=20)
d['City'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# ## ratings across the product line

# %%
d.groupby('Product line')['Rating'].mean().sort_values(ascending=False).to_frame()
# Out:
#                           Rating
# Product line
# Food and beverages      7.113218
# Fashion accessories     7.029213
# Health and beauty       7.003289
# Electronic accessories  6.924706
# Sports and travel       6.916265
# Home and lifestyle      6.837500

# %% [markdown]
# food and beverages have heighest rating

# %%
d.groupby('Customer type')['Rating'].mean()
# Out:
# Customer type
# Member    6.940319
# Normal    7.005210
# Name: Rating, dtype: float64

# %% [markdown]
# normal people are more happier than the members

# %%
plt.subplots(figsize=(15,10))
sns.barplot(x='Product line', y='Total', hue='Gender', data=d)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %% [markdown]
# ## Conclusion
# It turns out females are more likely to pay more for electronic accessories, home and lifestyle, food and beverages, and fashion accessories. Males only spent more on health and beauty and sports and travel. The company may benefit from marketing to the correct audience according to these figures.
#
# Through this preliminary analysis, I would suggest to the company that they should revamp their membership program because clearly it is not very effective. Based on the ratings, members are not any happier with service than non-members and they are only slightly more likely to spend more money. This should not be the case.
